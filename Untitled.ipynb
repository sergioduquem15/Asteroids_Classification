# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import urllib.request
import re
from bs4 import BeautifulSoup
import requests
from functools import reduce

# %%
import os

# %%
URL = 'http://smass.mit.edu/catalog.php'
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
table = soup.find_all('tr')[2:]
table[:10]
# Out:
# [<tr class="oddrow"><td class="mpnumber" rowspan="5">(1)</td><td class="mpname" rowspan="5">Ceres</td><td class="provdesig" rowspan="5"></td><td class="datalinks">Vis+NIR</td><td class="datalinks"><a href="data/spex/sp41/a000001.sp41.txt"><img alt="tabulated data file" src="_smassicons/tabulated.png"/></a> <a href="data/spex/sp41/sp41_plot.pdf"><img alt="graph of data" src="_smassicons/graph.png"/></a></td><td class="refnumber last"><a href="minus.html#unpublished">sp[041]</a></td><td>2012-11-20</td></tr>,
#  <tr class="oddrow"><td class="datalinks">Vis</td><td class="datalinks"><a href="data/smass/smass2/a000001.spfit.2.txt"><img alt="tabulated data file" src="_smassicons/tabulated.png"/></a></td><td class="refnumber last"><a href="smass.html#ref002">ref[02]</a></td><td>2004-05-23</td></tr>,
#  <tr class="oddrow"><td class="datalinks">Vis</td><td class="datalinks"><a href="data/smass/smass2/a000001.2.txt"><img alt="tabulated data file" src="_smassicons/tabulated.png"/></a></td><td class="refnumber last"><a href="smass.html#ref002">ref[02]</a></td><td>2004-05-23</td></tr>,
#  <tr class="oddrow"><td class="datalinks">NIR</td><td class="datalinks"><a href="data/spex/dm04/a000001.dm04.txt"><img alt="tabulated data file" src="_smassicons/tabulated.png"/></a> <a href="data/spex/dm04/dm04_plot.pdf"><img alt="graph of data" src="_smassicons/graph.png"/></a></td><td class="refnumber last"><a href="minus.html#unpublished">dm[004]</a></td><td>2019-06-15</td></tr>,
#  <tr class="oddrow"><td class="datalinks">NIR</td><td class="datalinks"><a href="data/smass/smassir/a000001.3.txt"><img alt="tabulated data file" src="_smassicons/tabulated.png"/></a></td><td class="refnumber last"><a href="smass.html#ref003">ref[03]</a></td><td>2004-05-23</td></tr>,
#  <tr class="evenrow"><td class="mpnumber" rowspan="4">(2)</td><td class="mpname" rowspan="4">Pallas</td><td class="provdesig" rowspan="4"></td><td class="datalinks">Vis+NIR</td><td class="datalinks"><a href="data/spex/sp89/a000002.sp89.txt"><img alt="tabulated data file" src="_smassicons/tabulated.png"/></a> <a href="data/spex/sp89/sp89_plot.pdf"><img alt="graph of data" src="_smassicons/graph.png"/></a></td><td class="refnumber last"><a href="minus.html#unpublished">sp[089]</a></td><td>2011-01-03</td></tr>,
#  <tr class="evenrow"><td class="datalinks">Vis</td><td class="datalinks"><a href="data/smass/smass2/a000002.2.txt"><img alt="tabulated data file" src="_smassicons/tabulated.png"/></a></td><td class="refnumber last"><a href="smass.html#ref002">ref[02]</a></td><td>2004-05-23</td></tr>,
#  <tr class="evenrow"><td class="datalinks">Vis</td><td class="datalinks"><a href="data/smass/smass2/a000002.spfit.2.txt"><img alt="tabulated data file" src="_smassicons/tabulated.png"/></a></td><td class="refnumber last"><a href="smass.html#ref002">ref[02]</a></td><td>2004-05-23</td></tr>,
#  <tr class="evenrow"><td class="datalinks">NIR</td><td class="datalinks"><a href="data/smass/smassir/a000002.3.txt"><img alt="tabulated data file" src="_smassicons/tabulated.png"/></a></td><td class="refnumber last"><a href="smass.html#ref003">ref[03]</a></td><td>2004-05-23</td></tr>,
#  <tr class="oddrow"><td class="mpnumber" rowspan="5">(3)</td><td class="mpname" rowspan="5">Juno</td><td class="provdesig" rowspan="5"></td><td class="datalinks">Vis+NIR</td><td class="datalinks"><a href="data/spex/sp96/a000003.sp96.txt"><img alt="tabulated data file" src="_smassicons/tabulated.png"/></a> <a href="data/spex/sp96/sp96_plot.pdf"><img alt="graph of data" src="_smassicons/graph.png"/></a></td><td class="refnumber last"><a href="minus.html#unpublished">sp[096]</a></td><td>2011-03-24</td></tr>]

# %%
name = np.array([])
file = np.array([])
for i in range(len(table)):
    t = table[i].findAll(True, {"class":["mpname", "datalinks"]})
    if len(t) == 3:
        n = re.findall('href="(data/spex/sp.*txt)"', str(t[2]))
        if len(n)==1 and t[0].text !="":
            file = np.append(n, file)
            name = np.append(t[0].text, name)

# %%
file
# Out:
# array(['data/spex/sp244/a398188.sp244.txt',
#        'data/spex/sp21/au1978CA.sp21.txt',
#        'data/spex/sp216/a100553.sp216.txt',
#        'data/spex/sp35/a099942subm.sp35.txt',
#        'data/spex/sp121/a096189.sp121n1.txt',
#        'data/spex/sp26/au1998FG2.sp26.txt',
#        'data/spex/sp273/a085119.sp273.txt',
#        'data/spex/sp60/a026858.sp60.txt',
#        'data/spex/sp87/a024761.sp87.txt',
#        'data/spex/sp108/a019652.sp108.txt',
#        'data/spex/sp25/a019127.sp25.txt',
#        'data/spex/sp02/a018106.sp02.txt',
#        'data/spex/sp273/a015817.sp273.txt',
#        'data/spex/sp82/a015745.sp82.txt',
#        'data/spex/sp117/a015107.sp117.txt',
#        'data/spex/sp44/a013553.sp44.txt',
#        'data/spex/sp215/a013551.sp215.txt',
#        'data/spex/sp98/a011885.sp98.txt',
#        'data/spex/sp65/a011500.sp65.txt',
#        'data/spex/sp117/a011284.sp117.txt',
#        'data/spex/sp88/a011066.sp88.txt',
#        'data/spex/sp119/a010295.sp119n2.txt',
#        'data/spex/sp56/a010195.sp56.txt',
#        'data/spex/sp119/a009983.sp119n2.txt',
#        'data/spex/sp125/a009950.sp125n1.txt',
#        'data/spex/sp25/a008444.sp25.txt',
#        'data/spex/sp124/a008306.sp124.txt',
#        'data/spex/sp93/a007472.sp93.txt',
#        'data/spex/sp117/a007468.sp117.txt',
#        'data/spex/sp226/a007343.sp226.txt',
#        'data/spex/sp93/a007336.sp93.txt',
#        'data/spex/sp59/a007304.sp59.txt',
#        'data/spex/sp110/a007172.sp110.txt',
#        'data/spex/sp29/a007092.sp29.txt',
#        'data/spex/sp222/a007088.sp222.txt',
#        'data/spex/sp55/a006585.sp55.txt',
#        'data/spex/sp243/a006569.sp243n2.txt',
#        'data/spex/sp253/a006478.sp253.txt',
#        'data/spex/sp43/a006456.sp43.txt',
#        'data/spex/sp28/a006411.sp28.txt',
#        'data/spex/sp36/a006386.sp36.txt',
#        'data/spex/sp93/a006249.sp93.txt',
#        'data/spex/sp27/a006239.sp27.txt',
#        'data/spex/sp125/a006070.sp125n1.txt',
#        'data/spex/sp26/a006063.sp26.txt',
#        'data/spex/sp280/a005879.sp280n2.txt',
#        'data/spex/sp217/a005863.sp217.txt',
#        'data/spex/sp31/a005817.sp31.txt',
#        'data/spex/sp08/a005786.sp08.txt',
#        'data/spex/sp67/a005720.sp67.txt',
#        'data/spex/sp35/a005653.sp35.txt',
#        'data/spex/sp30/a005642.sp30.txt',
#        'data/spex/sp81/a005620.sp81.txt',
#        'data/spex/sp101/a005577.sp101.txt',
#        'data/spex/sp95/a005392.sp95.txt',
#        'data/spex/sp51/a005379.sp51.txt',
#        'data/spex/sp47/a005332.sp47.txt',
#        'data/spex/sp290/a005330.sp290n1.txt',
#        'data/spex/sp41/a005261.sp41.txt',
#        'data/spex/sp201/a005159.sp201n1.txt',
#        'data/spex/sp55/a005143.sp55.txt',
#        'data/spex/sp107/a005026.sp107.txt',
#        'data/spex/sp56/a005011.sp56.txt',
#        'data/spex/sp123/a004905.sp123.txt',
#        'data/spex/sp111/a004769.sp111.txt',
#        'data/spex/sp109/a004674.sp109.txt',
#        'data/spex/sp253/a004581.sp253.txt',
#        'data/spex/sp89/a004580.sp89.txt',
#        'data/spex/sp29/a004558.sp29.txt',
#        'data/spex/sp58/a004544.sp58.txt',
#        'data/spex/sp02/a004486.sp02.txt',
#        'data/spex/sp85/a004455.sp85.txt',
#        'data/spex/sp124/a004450.sp124.txt',
#        'data/spex/sp107/a004402.sp107.txt',
#        'data/spex/sp203/a004401.sp203.txt',
#        'data/spex/sp223/a004341.sp223.txt',
#        'data/spex/sp103/a004183.sp103.txt',
#        'data/spex/sp03/a004179.sp03.txt',
#        'data/spex/sp81/a004015.sp81.txt',
#        'data/spex/sp32/a003873.sp32.txt',
#        'data/spex/sp28/a003858.sp28.txt',
#        'data/spex/sp92/a003833.sp92.txt',
#        'data/spex/sp84/a003819.sp84.txt',
#        'data/spex/sp121/a003749.sp121n2.txt',
#        'data/spex/sp51/a003703.sp51.txt',
#        'data/spex/sp68/a003691.sp68.txt',
#        'data/spex/sp91/a003671.sp91.txt',
#        'data/spex/sp47/a003635.sp47.txt',
#        'data/spex/sp91/a003613.sp91.txt',
#        'data/spex/sp78/a003554.sp78.txt',
#        'data/spex/sp94/a003485.sp94.txt',
#        'data/spex/sp25/a003402.sp25.txt',
#        'data/spex/sp45/a003361.sp45.txt',
#        'data/spex/sp50/a003317.sp50.txt',
#        'data/spex/sp67/a003288.sp67.txt',
#        'data/spex/sp39/a003248.sp39.txt',
#        'data/spex/sp97/a003029.sp97.txt',
#        'data/spex/sp96/a002990.sp96.txt',
#        'data/spex/sp65/a002956.sp65.txt',
#        'data/spex/sp56/a002919.sp56.txt',
#        'data/spex/sp57/a002867.sp57.txt',
#        'data/spex/sp48/a002850.sp48.txt',
#        'data/spex/sp48/a002823.sp48.txt',
#        'data/spex/sp263/a002616.sp263n1.txt',
#        'data/spex/sp89/a002463.sp89.txt',
#        'data/spex/sp93/a002449.sp93.txt',
#        'data/spex/sp40/a002378.sp40.txt',
#        'data/spex/sp239/a002368.sp239.txt',
#        'data/spex/sp203/a002340.sp203.txt',
#        'data/spex/sp230/a002329.sp230.txt',
#        'data/spex/sp40/a002311.sp40.txt',
#        'data/spex/sp39/a002246.sp39.txt',
#        'data/spex/sp57/a002212.sp57.txt',
#        'data/spex/sp35/a002195.sp35.txt',
#        'data/spex/sp49/a002107.sp49.txt',
#        'data/spex/sp45/a002099.sp45.txt',
#        'data/spex/sp25/a002074.sp25.txt',
#        'data/spex/sp52/a002064.sp52.txt',
#        'data/spex/sp41/a002063.sp41.txt',
#        'data/spex/sp206/a002062.sp206.txt',
#        'data/spex/sp243/a002061.sp243n1.txt',
#        'data/spex/sp45/a000024.sp45.txt',
#        'data/spex/sp96/a000023.sp96.txt',
#        'data/spex/sp55/a000022.sp55.txt',
#        'data/spex/sp31/a000021.sp31.txt',
#        'data/spex/sp96/a000020.sp96.txt',
#        'data/spex/sp48/a000019.sp48.txt',
#        'data/spex/sp96/a000017.sp96.txt',
#        'data/spex/sp58/a000016.sp58.txt',
#        'data/spex/sp28/a000015.sp28.txt',
#        'data/spex/sp25/a000014.sp25.txt',
#        'data/spex/sp41/a000013.sp41.txt',
#        'data/spex/sp47/a000011.sp47.txt',
#        'data/spex/sp75/a000009.sp75.txt',
#        'data/spex/sp28/a000007.sp28.txt',
#        'data/spex/sp67/a000006.sp67.txt',
#        'data/spex/sp28/a000005.sp28.txt',
#        'data/spex/sp86/a000004.sp86.txt',
#        'data/spex/sp96/a000003.sp96.txt',
#        'data/spex/sp89/a000002.sp89.txt',
#        'data/spex/sp41/a000001.sp41.txt'], dtype='<U35')

# %%
asteroid_download = np.hstack((file.reshape(-1,1), name.reshape(-1,1)))
asteroid_download.shape, asteroid_download[:2]
# Out:
# ((336, 2),
#  array([['data/spex/sp244/a398188.sp244.txt', 'Agni'],
#         ['data/spex/sp21/au1978CA.sp21.txt', 'Cacus']], dtype='<U35'))

# %%
for i,f in enumerate(file):
    filename = os.path.basename(f)
    print(f"Descargando {filename}...")
    url = "http://smass.mit.edu/"+f
    #data=urllib.request.urlopen(url).read().decode()
    os.system(f"wget -O {filename} {url}")
# Out:
# Descargando a398188.sp244.txt...
# Descargando au1978CA.sp21.txt...
# Descargando a100553.sp216.txt...
# Descargando a099942subm.sp35.txt...
# Descargando a096189.sp121n1.txt...
# Descargando au1998FG2.sp26.txt...
# Descargando a085119.sp273.txt...
# Descargando a026858.sp60.txt...
# Descargando a024761.sp87.txt...
# Descargando a019652.sp108.txt...
# Descargando a019127.sp25.txt...
# Descargando a018106.sp02.txt...
# Descargando a015817.sp273.txt...
# Descargando a015745.sp82.txt...
# Descargando a015107.sp117.txt...
# Descargando a013553.sp44.txt...
# Descargando a013551.sp215.txt...
# Descargando a011885.sp98.txt...
# Descargando a011500.sp65.txt...
# Descargando a011284.sp117.txt...
# Descargando a011066.sp88.txt...
# Descargando a010295.sp119n2.txt...
# Descargando a010195.sp56.txt...
# Descargando a009983.sp119n2.txt...
# Descargando a009950.sp125n1.txt...
# Descargando a008444.sp25.txt...
# Descargando a008306.sp124.txt...
# Descargando a007472.sp93.txt...
# Descargando a007468.sp117.txt...
# Descargando a007343.sp226.txt...
# Descargando a007336.sp93.txt...
# Descargando a007304.sp59.txt...
# Descargando a007172.sp110.txt...
# Descargando a007092.sp29.txt...
# Descargando a007088.sp222.txt...
# Descargando a006585.sp55.txt...
# Descargando a006569.sp243n2.txt...
# Descargando a006478.sp253.txt...
# Descargando a006456.sp43.txt...
# Descargando a006411.sp28.txt...
# Descargando a006386.sp36.txt...
# Descargando a006249.sp93.txt...
# Descargando a006239.sp27.txt...
# Descargando a006070.sp125n1.txt...
# Descargando a006063.sp26.txt...
# Descargando a005879.sp280n2.txt...
# Descargando a005863.sp217.txt...
# Descargando a005817.sp31.txt...
# Descargando a005786.sp08.txt...
# Descargando a005720.sp67.txt...
# Descargando a005653.sp35.txt...
# Descargando a005642.sp30.txt...
# Descargando a005620.sp81.txt...
# Descargando a005577.sp101.txt...
# Descargando a005392.sp95.txt...
# Descargando a005379.sp51.txt...
# Descargando a005332.sp47.txt...
# Descargando a005330.sp290n1.txt...
# Descargando a005261.sp41.txt...
# Descargando a005159.sp201n1.txt...
# Descargando a005143.sp55.txt...
# Descargando a005026.sp107.txt...
# Descargando a005011.sp56.txt...
# Descargando a004905.sp123.txt...
# Descargando a004769.sp111.txt...
# Descargando a004674.sp109.txt...
# Descargando a004581.sp253.txt...
# Descargando a004580.sp89.txt...
# Descargando a004558.sp29.txt...
# Descargando a004544.sp58.txt...
# Descargando a004486.sp02.txt...
# Descargando a004455.sp85.txt...
# Descargando a004450.sp124.txt...
# Descargando a004402.sp107.txt...
# Descargando a004401.sp203.txt...
# Descargando a004341.sp223.txt...
# Descargando a004183.sp103.txt...
# Descargando a004179.sp03.txt...
# Descargando a004015.sp81.txt...
# Descargando a003873.sp32.txt...
# Descargando a003858.sp28.txt...
# Descargando a003833.sp92.txt...
# Descargando a003819.sp84.txt...
# Descargando a003749.sp121n2.txt...
# Descargando a003703.sp51.txt...
# Descargando a003691.sp68.txt...
# Descargando a003671.sp91.txt...
# Descargando a003635.sp47.txt...
# Descargando a003613.sp91.txt...
# Descargando a003554.sp78.txt...
# Descargando a003485.sp94.txt...
# Descargando a003402.sp25.txt...
# Descargando a003361.sp45.txt...
# Descargando a003317.sp50.txt...
# Descargando a003288.sp67.txt...
# Descargando a003248.sp39.txt...
# Descargando a003029.sp97.txt...
# Descargando a002990.sp96.txt...
# Descargando a002956.sp65.txt...
# Descargando a002919.sp56.txt...
# Descargando a002867.sp57.txt...
# Descargando a002850.sp48.txt...
# Descargando a002823.sp48.txt...
# Descargando a002616.sp263n1.txt...
# Descargando a002463.sp89.txt...
# Descargando a002449.sp93.txt...
# Descargando a002378.sp40.txt...
# Descargando a002368.sp239.txt...
# Descargando a002340.sp203.txt...
# Descargando a002329.sp230.txt...
# Descargando a002311.sp40.txt...
# Descargando a002246.sp39.txt...
# Descargando a002212.sp57.txt...
# Descargando a002195.sp35.txt...
# Descargando a002107.sp49.txt...
# Descargando a002099.sp45.txt...
# Descargando a002074.sp25.txt...
# Descargando a002064.sp52.txt...
# Descargando a002063.sp41.txt...
# Descargando a002062.sp206.txt...
# Descargando a002061.sp243n1.txt...
# Descargando a002059.sp257.txt...
# Descargando a002036.sp96.txt...
# Descargando a001980.sp55.txt...
# Descargando a001951.sp72.txt...
# Descargando a001917.sp72.txt...
# Descargando a001916.sp07.txt...
# Descargando a001912.sp94.txt...
# Descargando a001910.sp85.txt...
# Descargando a001866.sp56.txt...
# Descargando a001865.sp75.txt...
# Descargando a001864.sp05.txt...
# Descargando a001857.sp263n1.txt...
# Descargando a001768.sp104.txt...
# Descargando a001709.sp97.txt...
# Descargando a001660.sp37.txt...
# Descargando a001640.sp37.txt...
# Descargando a001620.sp03.txt...
# Descargando a001589.sp123.txt...
# Descargando a001583.sp40.txt...
# Descargando a001580.sp14.txt...
# Descargando a001566.sp42.txt...
# Descargando a001565.sp36.txt...
# Descargando a001542.sp39.txt...
# Descargando a001508.sp28.txt...
# Descargando a001494.sp55.txt...
# Descargando a001468.sp25.txt...
# Descargando a001443.sp221.txt...
# Descargando a001406.sp64.txt...
# Descargando a001374.sp28.txt...
# Descargando a001332.sp42.txt...
# Descargando a001310.sp50.txt...
# Descargando a001300.sp55.txt...
# Descargando a001204.sp37.txt...
# Descargando a001180.sp46.txt...
# Descargando a001167.sp44.txt...
# Descargando a001143.sp42.txt...
# Descargando a001139.sp29.txt...
# Descargando a001131.sp28.txt...
# Descargando a001076.sp91.txt...
# Descargando a001065.sp37.txt...
# Descargando a001036.sp05.txt...
# Descargando a001021.sp89.txt...
# Descargando a001015.sp290n2.txt...
# Descargando a000984.sp92.txt...
# Descargando a000944.sp31.txt...
# Descargando a000939.sp101.txt...
# Descargando a000925.sp102.txt...
# Descargando a000908.sp53.txt...
# Descargando a000887.sp111.txt...
# Descargando a000863.sp76.txt...
# Descargando a000854.sp99.txt...
# Descargando a000845.sp89.txt...
# Descargando a000810.sp263n2.txt...
# Descargando a000808.sp92.txt...
# Descargando a000793.sp92.txt...
# Descargando a000785.sp41.txt...
# Descargando a000776.sp38.txt...
# Descargando a000773.sp31.txt...
# Descargando a000762.sp85.txt...
# Descargando a000747.sp290n2.txt...
# Descargando a000733.sp290n2.txt...
# Descargando a000720.sp97.txt...
# Descargando a000719.sp08.txt...
# Descargando a000706.sp48.txt...
# Descargando a000699.sp35.txt...
# Descargando a000679.sp89.txt...
# Descargando a000631.sp101.txt...
# Descargando a000617.sp40.txt...
# Descargando a000600.sp101.txt...
# Descargando a000596.sp97.txt...
# Descargando a000584.sp65.txt...
# Descargando a000570.sp28.txt...

# %%
asteroid_df = pd.read_csv('sbdb_query_results.csv', sep=',')
asteroid_df.head()
#spec_B = SMASSII,
# Out:
#                   full_name      a       e      i      om       w      q  \
# 0         1 Ceres (A801 AA)  2.766  0.0785  10.59   80.27   73.64  2.549
# 1        2 Pallas (A802 FA)  2.771  0.2300  34.93  172.92  310.70  2.134
# 2          3 Juno (A804 RA)  2.669  0.2569  12.99  169.85  247.94  1.983
# 3         4 Vesta (A807 FA)  2.361  0.0882   7.14  103.80  151.09  2.153
# 4       5 Astraea (A845 XA)  2.575  0.1901   5.37  141.57  358.74  2.086
#
#      ad  per.y  data_arc  ...  diameter                 extent  albedo  \
# 0  2.98   4.60      9520  ...   939.400  964.4 x 964.2 x 891.8  0.0900
# 1  3.41   4.61     79390  ...   513.000            568x532x448  0.1550
# 2  3.35   4.36     79279  ...   246.596                    NaN  0.2140
# 3  2.57   3.63     25743  ...   525.400  572.6 x 557.2 x 446.4  0.4228
# 4  3.06   4.13     64243  ...   106.699                    NaN  0.2740
#
#      rot_per         GM     BV     UB  IR  spec_B  spec_T
# 0   9.074170  62.628400  0.713  0.426 NaN       C       G
# 1   7.813221  13.630000  0.635  0.284 NaN       B       B
# 2   7.210000        NaN  0.824  0.433 NaN      Sk       S
# 3   5.342128  17.288245  0.782  0.492 NaN       V       V
# 4  16.806000        NaN  0.826  0.411 NaN       S       S
#
# [5 rows x 25 columns]

# %%
asteroid_df["full_name2"] = asteroid_df["full_name"].apply( lambda x: x.split(" ")[-3])

# %%
spectral_type = np.array([])
file2 = np.array([])
name2 = np.array([])
for i in range(asteroid_df.shape[0]):
    for j in range(asteroid_download.shape[0]):
        if asteroid_df.full_name2[i] == asteroid_download[j,1]:
            spectral_type = np.append(asteroid_df.spec_B[i], spectral_type)
            name2 = np.append(asteroid_df.full_name2[i], name2)
            file2 = np.append(asteroid_download[j, 0], file2)

# %%
spectral_type
# Out:
# array(['V', 'B', 'S', 'Sr', 'T', 'D', 'Sr', 'Ld', 'Cgh', 'D', 'S', 'S',
#        'C', 'S', 'Sa', 'Ld', 'Ld', 'Cg', 'C', 'B', 'Xc', 'Sr', 'S', 'L',
#        'A', 'Sq', 'S', 'Cb', 'Cgh', 'T', 'C', 'Sq', 'Cgh', 'K', 'S', 'S',
#        'T', 'Sl', 'T', 'Sq', 'S', 'Sl', 'C', 'S', 'S', 'Ch', 'S', 'Ch',
#        'K', 'T', 'C', 'S', 'X', 'Ld', 'Ch', 'S', 'X', 'Xk', 'Xc', 'A',
#        'S', 'Sa', 'S', 'L', 'Ld', 'B', 'Cb', 'Xc', 'Sk', 'X', 'S', 'Sl',
#        'Cb', 'Xk', 'Sq', 'Cg', 'Xk', 'Ch', 'X', 'C', 'S', 'X', 'Sl', 'B',
#        'Ch', 'Xc', 'C', 'Ch', 'Sl', 'S', 'X', 'Xk', 'S', 'Ch', 'X', 'Sl',
#        'Ch', 'S', 'S', 'Xk', 'T', 'C', 'B', 'X', 'Sq', 'Cb', 'S', 'Ch',
#        'Xe', 'X', 'X', 'S', 'Ch', 'Xc', 'Sa', 'Ch', 'S', 'Ch', 'S', 'Xk',
#        'X', 'C', 'C', 'Ch', 'Ch', 'Ch', 'B', 'C', 'Xc', 'Sk', 'Ch', 'S',
#        'S', 'Cgh', 'S', 'Ch', 'S', 'Sl', 'S', 'S', 'S', 'S', 'B', 'S',
#        'X', 'Xk', 'S', 'Ch', 'Sl', 'X', 'S', 'S', 'Ch', 'Sk', 'S', 'S',
#        'S', 'V', 'Sk', 'B', 'C'], dtype='<U32')

# %%
name2
# Out:
# array(['Abehiroshi', 'Senrikyu', 'Burbine', 'Robinson', 'Paris',
#        'Farinella', 'Yeomans', 'Mozhaiskij', 'Pannekoek', 'Bowell',
#        'Ilmari', 'Parchomenko', 'Appenzella', 'Wood', 'Savo', 'Komppa',
#        'Marconia', 'Marcelle', 'Viola', 'Flammario', 'Christa', 'Gretia',
#        'Alphonsina', 'Buda', 'Benkoela', 'Merxia', 'Arizona', 'Zwetana',
#        'Berbericia', 'Irmintraud', 'Winchester', 'Bohlinia', 'Hirundo',
#        'Pax', 'Philippina', 'Musa', 'Scheila', 'Semiramis', 'Kythera',
#        'Nassovia', 'Herculina', 'Vaticana', 'Elisabetha', 'Cyane',
#        'Industria', 'Campania', 'Bohemia', 'Tercidina', 'Dorothea',
#        'Polyxo', 'Bavaria', 'Glauke', 'Thule', 'Justitia', 'Aline',
#        'Libussa', 'Prymno', 'Bettina', 'Eukrate', 'Asporina', 'Vera',
#        'Sita', 'Coelestina', 'Honoria', 'Barbara', 'Lilaea', 'Isabella',
#        'Dido', 'Lacrimosa', 'Penelope', 'Philomela', 'Nausikaa', 'Kolga',
#        'Eucharis', 'Garumna', 'Andromache', 'Ino', 'Sibylla', 'Eva',
#        'Una', 'Koronis', 'Hilda', 'Abundantia', 'Polana', 'Lumen', 'Vala',
#        'Nemesis', 'Hermione', 'Althaea', 'Peitho', 'Lomia', 'Kassandra',
#        'Amalthea', 'Ate', 'Lydia', 'Hecuba', 'Artemis', 'Hera', 'Helena',
#        'Dike', 'Aegle', 'Antiope', 'Thisbe', 'Sylvia', 'Alkmene',
#        'Terpsichore', 'Eurynome', 'Diana', 'Frigga', 'Freia', 'Hesperia',
#        'Asia', 'Maja', 'Cybele', 'Ausonia', 'Erato', 'Echo', 'Concordia',
#        'Mnemosyne', 'Melete', 'Pandora', 'Alexandra', 'Europa', 'Nemausa',
#        'Virginia', 'Doris', 'Aglaja', 'Eugenia', 'Nysa', 'Ariadne',
#        'Daphne', 'Harmonia', 'Laetitia', 'Leda', 'Fides', 'Circe',
#        'Pomona', 'Urania', 'Amphitrite', 'Euterpe', 'Proserpina',
#        'Phocaea', 'Themis', 'Thalia', 'Kalliope', 'Lutetia', 'Massalia',
#        'Fortuna', 'Thetis', 'Psyche', 'Eunomia', 'Irene', 'Egeria',
#        'Parthenope', 'Iris', 'Hebe', 'Astraea', 'Vesta', 'Juno', 'Pallas',
#        'Ceres'], dtype='<U32')

# %%
file2
# Out:
# array(['data/spex/sp51/a005379.sp51.txt',
#        'data/spex/sp290/a005330.sp290n1.txt',
#        'data/spex/sp201/a005159.sp201n1.txt',
#        'data/spex/sp84/a003819.sp84.txt',
#        'data/spex/sp50/a003317.sp50.txt',
#        'data/spex/sp39/a003248.sp39.txt',
#        'data/spex/sp65/a002956.sp65.txt',
#        'data/spex/sp48/a002850.sp48.txt',
#        'data/spex/sp40/a002378.sp40.txt',
#        'data/spex/sp39/a002246.sp39.txt',
#        'data/spex/sp49/a002107.sp49.txt',
#        'data/spex/sp263/a001857.sp263n1.txt',
#        'data/spex/sp104/a001768.sp104.txt',
#        'data/spex/sp37/a001660.sp37.txt',
#        'data/spex/sp55/a001494.sp55.txt',
#        'data/spex/sp64/a001406.sp64.txt',
#        'data/spex/sp42/a001332.sp42.txt',
#        'data/spex/sp55/a001300.sp55.txt',
#        'data/spex/sp91/a001076.sp91.txt',
#        'data/spex/sp89/a001021.sp89.txt',
#        'data/spex/sp290/a001015.sp290n2.txt',
#        'data/spex/sp92/a000984.sp92.txt',
#        'data/spex/sp102/a000925.sp102.txt',
#        'data/spex/sp53/a000908.sp53.txt',
#        'data/spex/sp76/a000863.sp76.txt',
#        'data/spex/sp92/a000808.sp92.txt',
#        'data/spex/sp92/a000793.sp92.txt',
#        'data/spex/sp41/a000785.sp41.txt',
#        'data/spex/sp38/a000776.sp38.txt',
#        'data/spex/sp31/a000773.sp31.txt',
#        'data/spex/sp41/a000001.sp41.txt'], dtype='<U35')

# %%
len(spectral_type), len(name2), len(file2)
# Out:
# (161, 161, 161)

# %%
asteroid_df_final = pd.DataFrame({'nombre': name2, 'smass': spectral_type, 'file': file2})
asteroid_df_final['file'] = asteroid_df_final.file.apply(lambda x: x.split('/')[-1])
asteroid_df_final.head(20)
# Out:
#          nombre smass                 file
# 0    Abehiroshi     V     a005379.sp51.txt
# 1      Senrikyu     B  a005330.sp290n1.txt
# 2       Burbine     S  a005159.sp201n1.txt
# 3      Robinson    Sr     a003819.sp84.txt
# 4         Paris     T     a003317.sp50.txt
# 5     Farinella     D     a003248.sp39.txt
# 6       Yeomans    Sr     a002956.sp65.txt
# 7    Mozhaiskij    Ld     a002850.sp48.txt
# 8     Pannekoek   Cgh     a002378.sp40.txt
# 9        Bowell     D     a002246.sp39.txt
# 10       Ilmari     S     a002107.sp49.txt
# 11  Parchomenko     S  a001857.sp263n1.txt
# 12   Appenzella     C    a001768.sp104.txt
# 13         Wood     S     a001660.sp37.txt
# 14         Savo    Sa     a001494.sp55.txt
# 15       Komppa    Ld     a001406.sp64.txt
# 16     Marconia    Ld     a001332.sp42.txt
# 17     Marcelle    Cg     a001300.sp55.txt
# 18        Viola     C     a001076.sp91.txt
# 19    Flammario     B     a001021.sp89.txt

# %%
df_list = []
for i in range(asteroid_df_final.shape[0]):
    df = pd.read_csv(asteroid_df_final.file[i], delim_whitespace=True, names = ['wavelenght', 'intensity', 'error', '-'])
    df.drop(['error', '-'], axis=1, inplace=True)
    df_list.append(df)

# %%
len(df_list)
# Out:
# 161

# %%
from scipy.interpolate import interp1d

# %%
df_list[-1]
# Out:
#      wavelenght  intensity
# 0        0.4350     0.9004
# 1        0.4375     0.9186
# 2        0.4400     0.9308
# 3        0.4425     0.9394
# 4        0.4450     0.9355
# ..          ...        ...
# 522      2.4700     1.0051
# 523      2.4750     1.0077
# 524      2.4800     1.0056
# 525      2.4850     1.0169
# 526      2.4900     1.0118
#
# [527 rows x 2 columns]

# %%
df_list[-1].drop_duplicates(inplace=True)
# Out:
#      intensity
# 0       0.9004
# 1       0.9186
# 2       0.9308
# 3       0.9394
# 4       0.9355
# ..         ...
# 513     1.0061
# 518     1.0110
# 522     1.0051
# 525     1.0169
# 526     1.0118
#
# [382 rows x 1 columns]

# %%
df_list[-1].index = range(len(df_list[-1]))
ast_index = df_list[-1][df_list[-1].wavelenght.duplicated()].index
df_list[-1].drop(ast_index, inplace=True)

# %%
df_list[-1]
# Out:
#      wavelenght  intensity
# 0        0.4350     0.9004
# 1        0.4375     0.9186
# 2        0.4400     0.9308
# 3        0.4425     0.9394
# 4        0.4450     0.9355
# ..          ...        ...
# 522      2.4700     1.0051
# 523      2.4750     1.0077
# 524      2.4800     1.0056
# 525      2.4850     1.0169
# 526      2.4900     1.0118
#
# [505 rows x 2 columns]

# %%
df_list[-1].index = range(len(df_list[-1]))
x = df_list[-1].wavelenght
y = np.abs(df_list[-1].intensity)

# %%
old = np.linspace(min(x),max(x),200,endpoint=True)

# %%
f = interp1d(x,y,kind='cubic')
ax = plt.subplot(121)

ax.plot(x,y,".",alpha=0.6)
ax.plot(old,f(old))

# %%
pd.DataFrame({'wave':old, 'int':f(old)})
# Out:
#          wave       int
# 0    0.435000  0.900400
# 1    0.445327  0.935479
# 2    0.455653  0.955976
# 3    0.465980  0.957018
# 4    0.476307  0.961257
# ..        ...       ...
# 195  2.448693  1.009981
# 196  2.459020  1.002552
# 197  2.469347  1.006189
# 198  2.479673  1.005404
# 199  2.490000  1.011800
#
# [200 rows x 2 columns]

# %%
df_merged = reduce(lambda left, right: pd.merge(left, right, left_index=True, right_index=True, how='outer'), df_list[:20])

# %%
df_merged.columns = asteroid_df_final.nombre[:20]

# %%
df_merged.T
# Out:
# wavelenght   0.4350  0.4375  0.4400  0.4425  0.4450  0.4475  0.4500  0.4525  \
# nombre
# Abehiroshi   0.9166     NaN     NaN     NaN  0.7647  0.7489  0.9765  0.8378
# Senrikyu     1.1470  1.0709  1.0085  1.0562  0.9962  1.0437  1.1423  1.0905
# Burbine      0.8881  0.4939  0.6462  0.7592  0.9368  0.8562  0.7991  0.7573
# Robinson     0.7190  0.7323  0.7803  0.7416  0.7912  0.8208  0.8445  0.7609
# Paris        0.9251  0.9300  0.9549  0.9424  0.9815  0.9156  0.9238  0.9345
# Farinella    0.7594  0.8364  0.7036  0.7929  0.8981  0.8879  0.8795  0.9669
# Yeomans      0.7946  0.7614  0.7661  0.7094  0.7858  0.8156  0.8135  0.8002
# Mozhaiskij   0.7424     NaN  0.7552  0.8202  0.7208  0.7517  0.7687  0.7990
# Pannekoek       NaN  0.8587     NaN     NaN  0.8892  0.9325  0.8882  0.9235
# Bowell       0.8985  0.8220  0.8570  0.8812  0.8981  0.9008  0.8920  0.9169
# Ilmari       0.7530  0.7648  0.7657  0.8200  0.8000  0.8398  0.8460  0.7999
# Parchomenko  0.8039  0.7483  0.7645  0.8031  0.8583  0.8136  0.8148  0.7858
# Appenzella   0.7970  0.9005  0.9455  1.0200  0.9869  0.8887  0.9271  0.9124
# Wood         0.8210  0.8213  0.8287  0.8342  0.8426  0.8181  0.8547  0.8500
# Savo         0.7480  0.6910  0.7322  0.8081  0.8025  0.7828  0.8193  0.8145
# Komppa       0.8638  0.8403  0.9559  0.9295  0.8927  0.8838  0.8487  0.8557
# Marconia     0.7386  0.7417  0.7287  0.8304  0.7257  0.8484  0.8216  0.8382
# Marcelle     0.6976  0.7814  0.7860  0.8064  0.9210  0.9170  0.8792  0.9024
# Viola        0.9087  0.8905  0.9091  0.8862  0.9228  0.9718  0.9520  0.9645
# Flammario    1.0097  1.0152  1.0268  1.0364  1.0053  1.0116  1.0530  1.0275
#
# wavelenght   0.4550  0.4575  ...  2.4450  2.4500  2.4550  2.4600  2.4650  \
# nombre                       ...
# Abehiroshi   0.8373  0.9923  ...  1.3508  1.3453  1.3766 -1.0000 -1.0000
# Senrikyu     1.0375  0.9493  ... -1.0000 -1.0000 -1.0000 -1.0000 -1.0000
# Burbine      0.8010  0.9608  ...     NaN     NaN     NaN     NaN     NaN
# Robinson     0.8080  0.7786  ...  1.7287  1.7467 -1.0000 -1.0000 -1.0000
# Paris        0.9272  0.9439  ... -1.0000 -1.0000 -1.0000  1.9512  1.9182
# Farinella    0.9130  0.7835  ...  1.9768  1.9289  1.9766  1.9372 -1.0000
# Yeomans      0.8070  0.8236  ... -1.0000  1.4391 -1.0000 -1.0000 -1.0000
# Mozhaiskij   0.7391  0.7602  ...  1.6176  1.6154 -1.0000 -1.0000 -1.0000
# Pannekoek    0.9643  0.9465  ... -1.0000 -1.0000 -1.0000 -1.0000 -1.0000
# Bowell       0.8953  0.8887  ...  2.0102  2.0284 -1.0000 -1.0000  2.0238
# Ilmari       0.8244  0.8607  ...  1.5140 -1.0000 -1.0000 -1.0000 -1.0000
# Parchomenko  0.8585  0.8187  ... -1.0000  1.7011  1.6731  1.7055 -1.0000
# Appenzella   0.9467  0.9462  ...  1.1435  1.1338 -1.0000 -1.0000 -1.0000
# Wood         0.8546  0.8586  ...  1.3481 -1.0000  1.3631 -1.0000  1.3626
# Savo         0.7918  0.8079  ...  1.6049  1.6132 -1.0000 -1.0000 -1.0000
# Komppa       0.8337  0.8744  ...  2.7213  2.7365  2.8158  2.7910  2.8323
# Marconia     0.8242  0.7312  ... -1.0000 -1.0000 -1.0000 -1.0000 -1.0000
# Marcelle     0.8723  0.7994  ...  1.1512 -1.0000  1.1819  1.1287  1.1516
# Viola        0.9657  0.9471  ... -1.0000  1.0430 -1.0000 -1.0000 -1.0000
# Flammario    1.0167  1.0243  ...  0.9813  0.9969 -1.0000 -1.0000 -1.0000
#
# wavelenght   2.4700  2.4750  2.4800  2.4850  2.4900
# nombre
# Abehiroshi  -1.0000 -1.0000    -1.0    -1.0    -1.0
# Senrikyu    -1.0000 -1.0000    -1.0    -1.0    -1.0
# Burbine         NaN     NaN     NaN     NaN     NaN
# Robinson    -1.0000 -1.0000    -1.0    -1.0    -1.0
# Paris        1.9327  1.9117    -1.0    -1.0    -1.0
# Farinella    1.9531 -1.0000    -1.0    -1.0    -1.0
# Yeomans     -1.0000 -1.0000    -1.0    -1.0    -1.0
# Mozhaiskij  -1.0000 -1.0000    -1.0    -1.0    -1.0
# Pannekoek   -1.0000 -1.0000    -1.0    -1.0    -1.0
# Bowell       2.0299 -1.0000    -1.0    -1.0    -1.0
# Ilmari      -1.0000 -1.0000    -1.0    -1.0    -1.0
# Parchomenko -1.0000  1.6686    -1.0    -1.0    -1.0
# Appenzella  -1.0000 -1.0000    -1.0    -1.0    -1.0
# Wood         1.3650 -1.0000    -1.0    -1.0    -1.0
# Savo        -1.0000 -1.0000    -1.0    -1.0    -1.0
# Komppa      -1.0000 -1.0000    -1.0    -1.0    -1.0
# Marconia    -1.0000 -1.0000    -1.0    -1.0    -1.0
# Marcelle     1.1337 -1.0000    -1.0    -1.0    -1.0
# Viola       -1.0000 -1.0000    -1.0    -1.0    -1.0
# Flammario   -1.0000 -1.0000    -1.0    -1.0    -1.0
#
# [20 rows x 17960496 columns]

# %%
df_colum = pd.DataFrame()
for i in range(0, 44, 11):
    print(i+11)
    df_merged = reduce(lambda left, right: pd.merge(left, right, left_index=True, right_index=True, how='outer'), df_list[i:i+11])
    df_colum = pd.merge(df_colum, df_merged, left_index=True, right_index=True, how='outer')

#df_colum.columns = asteroid_df_final.nombre[:44]
# Out:
# 11
# 22
# 33

# %%
df_merged.shape
# Out:
# (528, 1)

# %%
df_colum.head()
# Out:
#             intensity_x  intensity_y  intensity_x  intensity_y
# wavelenght
# 0.4350           0.9166       0.8039       0.7889       0.8508
# 0.4375              NaN       0.7483       0.8243       0.8625
# 0.4400              NaN       0.7645       0.8621       0.8532
# 0.4425              NaN       0.8031       0.8474       0.8980
# 0.4450           0.7647       0.8583       0.8339       0.8583

# %%
df_colum.shape
# Out:
# (873, 4)

# %%
df_merged = reduce(lambda left, right: pd.merge(left, right, left_index=True, right_index=True, how='outer'), df_list[:10])
df_merged.columns = asteroid_df_final.nombre[:10]
df_merged
# Out:
# nombre      Abehiroshi  Senrikyu  Burbine  Robinson   Paris  Farinella  \
# wavelenght
# 0.4350          0.9166    1.1470   0.8881    0.7190  0.9251     0.7594
# 0.4375             NaN    1.0709   0.4939    0.7323  0.9300     0.8364
# 0.4400             NaN    1.0085   0.6462    0.7803  0.9549     0.7036
# 0.4425             NaN    1.0562   0.7592    0.7416  0.9424     0.7929
# 0.4450          0.7647    0.9962   0.9368    0.7912  0.9815     0.8981
# ...                ...       ...      ...       ...     ...        ...
# 2.4700         -1.0000   -1.0000      NaN   -1.0000  1.9327     1.9531
# 2.4750         -1.0000   -1.0000      NaN   -1.0000  1.9117    -1.0000
# 2.4800         -1.0000   -1.0000      NaN   -1.0000 -1.0000    -1.0000
# 2.4850         -1.0000   -1.0000      NaN   -1.0000 -1.0000    -1.0000
# 2.4900         -1.0000   -1.0000      NaN   -1.0000 -1.0000    -1.0000
#
# nombre      Yeomans  Mozhaiskij  Pannekoek  Bowell
# wavelenght
# 0.4350       0.7946      0.7424        NaN  0.8985
# 0.4375       0.7614         NaN     0.8587  0.8220
# 0.4400       0.7661      0.7552        NaN  0.8570
# 0.4425       0.7094      0.8202        NaN  0.8812
# 0.4450       0.7858      0.7208     0.8892  0.8981
# ...             ...         ...        ...     ...
# 2.4700      -1.0000     -1.0000    -1.0000  2.0299
# 2.4750      -1.0000     -1.0000    -1.0000 -1.0000
# 2.4800      -1.0000     -1.0000    -1.0000 -1.0000
# 2.4850      -1.0000     -1.0000    -1.0000 -1.0000
# 2.4900      -1.0000     -1.0000    -1.0000 -1.0000
#
# [20863 rows x 10 columns]

# %%
df_merged = pd.concat(df_list, join='outer', axis=1).fillna(NaN)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-f4d64969b828> in <module>
# ----> 1 df_merged = pd.concat(df_list, join='outer', axis=1).fillna(NaN)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282     )
#     283
# --> 284     return op.get_result()
#     285
#     286
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     495
#     496             new_data = concatenate_block_managers(
# --> 497                 mgrs_indexers, self.new_axes, concat_axis=self.axis, copy=self.copy
#     498             )
#     499             if not self.copy:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2025         blocks.append(b)
#    2026
# -> 2027     return BlockManager(blocks, axes)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, do_integrity_check)
#     137
#     138         if do_integrity_check:
# --> 139             self._verify_integrity()
#     140
#     141         self._consolidate_check()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in _verify_integrity(self)
#     332         for block in self.blocks:
#     333             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# --> 334                 construction_error(tot_items, block.shape[1:], self.axes)
#     335         if len(self.items) != tot_items:
#     336             raise AssertionError(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in construction_error(tot_items, block_shape, axes, e)
#    1692     if block_shape[0] == 0:
#    1693         raise ValueError("Empty data passed with indices specified.")
# -> 1694     raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#    1695
#    1696
#
# ValueError: Shape of passed values is (743, 161), indices imply (680, 161)

# %%
df.join(tp_df, how='outer')
# Out:
#        intensity
# 0         0.9166
# 1         0.7647
# 2         0.7489
# 3         0.9765
# 4         0.8378
# ...          ...
# 85471     1.0051
# 85472     1.0077
# 85473     1.0056
# 85474     1.0169
# 85475     1.0118
#
# [85476 rows x 1 columns]

# %%
df_merged[df_merged < 0] = np.NaN

# %%
df_merged
# Out:
# nombre      Abehiroshi  Senrikyu  Burbine  Robinson   Paris  Farinella  \
# wavelenght
# 0.4350          0.9166    1.1470   0.8881    0.7190  0.9251     0.7594
# 0.4375             NaN    1.0709   0.4939    0.7323  0.9300     0.8364
# 0.4400             NaN    1.0085   0.6462    0.7803  0.9549     0.7036
# 0.4425             NaN    1.0562   0.7592    0.7416  0.9424     0.7929
# 0.4450          0.7647    0.9962   0.9368    0.7912  0.9815     0.8981
# ...                ...       ...      ...       ...     ...        ...
# 2.4700             NaN       NaN      NaN       NaN  1.9327     1.9531
# 2.4750             NaN       NaN      NaN       NaN  1.9117        NaN
# 2.4800             NaN       NaN      NaN       NaN     NaN        NaN
# 2.4850             NaN       NaN      NaN       NaN     NaN        NaN
# 2.4900             NaN       NaN      NaN       NaN     NaN        NaN
#
# nombre      Yeomans  Mozhaiskij  Pannekoek  Bowell  Ilmari  Parchomenko  \
# wavelenght
# 0.4350       0.7946      0.7424        NaN  0.8985  0.7530       0.8039
# 0.4375       0.7614         NaN     0.8587  0.8220  0.7648       0.7483
# 0.4400       0.7661      0.7552        NaN  0.8570  0.7657       0.7645
# 0.4425       0.7094      0.8202        NaN  0.8812  0.8200       0.8031
# 0.4450       0.7858      0.7208     0.8892  0.8981  0.8000       0.8583
# ...             ...         ...        ...     ...     ...          ...
# 2.4700          NaN         NaN        NaN  2.0299     NaN          NaN
# 2.4750          NaN         NaN        NaN     NaN     NaN       1.6686
# 2.4800          NaN         NaN        NaN     NaN     NaN          NaN
# 2.4850          NaN         NaN        NaN     NaN     NaN          NaN
# 2.4900          NaN         NaN        NaN     NaN     NaN          NaN
#
# nombre      Appenzella    Wood    Savo  Komppa  Marconia  Marcelle   Viola  \
# wavelenght
# 0.4350          0.7970  0.8210  0.7480  0.8638    0.7386    0.6976  0.9087
# 0.4375          0.9005  0.8213  0.6910  0.8403    0.7417    0.7814  0.8905
# 0.4400          0.9455  0.8287  0.7322  0.9559    0.7287    0.7860  0.9091
# 0.4425          1.0200  0.8342  0.8081  0.9295    0.8304    0.8064  0.8862
# 0.4450          0.9869  0.8426  0.8025  0.8927    0.7257    0.9210  0.9228
# ...                ...     ...     ...     ...       ...       ...     ...
# 2.4700             NaN  1.3650     NaN     NaN       NaN    1.1337     NaN
# 2.4750             NaN     NaN     NaN     NaN       NaN       NaN     NaN
# 2.4800             NaN     NaN     NaN     NaN       NaN       NaN     NaN
# 2.4850             NaN     NaN     NaN     NaN       NaN       NaN     NaN
# 2.4900             NaN     NaN     NaN     NaN       NaN       NaN     NaN
#
# nombre      Flammario
# wavelenght
# 0.4350         1.0097
# 0.4375         1.0152
# 0.4400         1.0268
# 0.4425         1.0364
# 0.4450         1.0053
# ...               ...
# 2.4700            NaN
# 2.4750            NaN
# 2.4800            NaN
# 2.4850            NaN
# 2.4900            NaN
#
# [17960496 rows x 20 columns]

# %%
df_merged.Ceres.plot()

# %%
df_transposed = df_merged.T
df_transposed.head()
